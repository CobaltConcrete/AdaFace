# %%
# !git clone https://github.com/Media-Smart/vedadet.git
# %cd vedadet
# !vedadet_root=${PWD}
# Out:
# Cloning into 'vedadet'...
# remote: Enumerating objects: 1035, done.
# remote: Total 1035 (delta 0), reused 0 (delta 0), pack-reused 1035
# Receiving objects: 100% (1035/1035), 1.19 MiB | 0 bytes/s, done.
# Resolving deltas: 100% (470/470), done.
# /home/UG/ganq0002/Projects/AdaFace/vedadet

# %%
# !dir
# %cd ..
# Out:
# frame0_0.jpg   frame2466.jpg  frame3933.jpg  frame53.jpg    frame6880.jpg
# frame0.jpg     frame2467.jpg  frame3934.jpg  frame5400.jpg  frame6881.jpg
# frame1000.jpg  frame2468.jpg  frame3935.jpg  frame5401.jpg  frame6882.jpg
# frame1001.jpg  frame2469.jpg  frame3936.jpg  frame5402.jpg  frame6883.jpg
# frame1002.jpg  frame246.jpg   frame3937.jpg  frame5403.jpg  frame6884.jpg
# frame1003.jpg  frame2470.jpg  frame3938.jpg  frame5404.jpg  frame6885.jpg
# frame1004.jpg  frame2471.jpg  frame3939.jpg  frame5405.jpg  frame6886.jpg
# frame1005.jpg  frame2472.jpg  frame393.jpg   frame5406.jpg  frame6887.jpg
# frame1006.jpg  frame2473.jpg  frame3940.jpg  frame5407.jpg  frame6888.jpg
# frame1007.jpg  frame2474.jpg  frame3941.jpg  frame5408.jpg  frame6889.jpg
# frame1008.jpg  frame2475.jpg  frame3942.jpg  frame5409.jpg  frame688.jpg
# frame1009.jpg  frame2476.jpg  frame3943.jpg  frame54_0.jpg  frame6890.jpg
# frame10_0.jpg  frame2477.jpg  frame3944.jpg  frame540.jpg   frame6891.jpg
# ...

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available.")
else:
    print("CUDA is not available.")
# Out:
# CUDA is available.

# %%
# !dir
# Out:
# assets		   head.py	     README.md	       train_val.py
# config.py	   inference.py      README_TRAIN.md   Untitled1.ipynb
# convert.py	   LICENSE	     requirements.txt  Untitled.ipynb
# data.py		   main.py	     run.py	       utils.py
# dataset		   net.py	     scripts	       validation_hq
# detector.py	   output_video.avi  testing0.jpg      validation_lq
# evaluate_utils.py  play_video.py     testing.jpg       validation_mixed
# face_alignment	   pretrained	     test.py	       vedadet
# face.jpg	   processed_frames  test_videos
# gcc-7.5.0	   __pycache__	     tina.ipynb

# %%
# %cd objdir
# !ls
# Out:
# [Errno 2] No such file or directory: 'objdir'
# /home/UG/ganq0002/Projects/AdaFace/gcc-7.5.0/objdir
# config.log

# %%
# !$HOME
# Out:
# /bin/bash: /home/UG/ganq0002: Is a directory

# %%
# !./configure --prefix=/home/UG/ganq0002/Projects/AdaFace/gcc-7.5.0 --enable-languages=c,c++ --disable-multilib
# Out:
# configure: error: cannot find install-sh, install.sh, or shtool in "." "./.." "./../.."

# %%
# !make install
# Build and install GCC
# !make -j$(nproc)
# !make install

# Update environment variables
# !export PATH=$HOME/local/gcc-7.5.0/bin:$PATH
# !export LD_LIBRARY_PATH=$HOME/local/gcc-7.5.0/lib64:$LD_LIBRARY_PATH

# Verify the GCC installation
# !gcc --version
# Out:
# make: *** No rule to make target `install'.  Stop.
# make: *** No targets specified and no makefile found.  Stop.
# make: *** No rule to make target `install'.  Stop.
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %cd gcc-7.5.0
# Out:
# /home/UG/ganq0002/Projects/AdaFace/gcc-7.5.0

# %%
# Out:
# Error: error: You must run this script in the top-level GCC source directory
#
# Failed to download prerequisites.
# Error occurred. Further steps cannot be executed.

# %%
# !export PATH=$HOME/local/gcc-7.5.0/bin:$PATH
# !export LD_LIBRARY_PATH=$HOME/local/gcc-7.5.0/lib64:$LD_LIBRARY_PATH

# %%
# !./configure --prefix=$HOME/local/gcc-7.5.0 --enable-languages=c,c++ --disable-multilib
# Out:
# configure: error: cannot find install-sh, install.sh, or shtool in "." "./.." "./../.."

# %%
# Create a directory for GCC build
# !mkdir -p gcc-7.5.0/objdir
# !cd gcc-7.5.0/objdir && ../configure --prefix=$HOME/local/gcc-7.5.0 --enable-languages=c,c++ --disable-multilib

# %%
# Build and install
# !cd gcc-7.5.0/objdir && make -j$(nproc) && make install
